# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import os
import glob

# %%
filename1 = '/Users/Magnus/PhD/Code/MATLAB/Scripts/15_Circumferential_iterations/features_table.txt'
filename2 = '/Users/Magnus/PhD/Code/MATLAB/Scripts/15_Circumferential_iterations/features_table_random.txt'

# %%
df_raw1 = pd.read_csv(filename1)
df_raw2 = pd.read_csv(filename2)
frames = [df_raw1, df_raw2]
df_raw = pd.concat(frames)

# %%
len(df_raw)
# Out:
# 900

# %%
gridsize = 0.2; # mm

# %%
#Computes thickness in mm from number of nodes and gridsize
df_raw['ModelThickMax'] = gridsize * df_raw['ModelThickMax']
df_raw['ModelThickMin'] = gridsize * df_raw['ModelThickMin']
df_raw['ModelThickDiff'] = gridsize * df_raw['ModelThickDiff']
df_raw['ModelThickMedian'] = gridsize * df_raw['ModelThickMedian']
df_raw['ModelThickMean'] = gridsize * df_raw['ModelThickMean']
df_raw['ModelThickStd'] = gridsize * df_raw['ModelThickStd']

# %%
df_raw
# Out:
#      ModelThickMax  ModelThickMin  ModelThickDiff  ModelThickMedian  \
# 0             12.2           12.2             0.0              12.2
# 1             12.2           12.2             0.0              12.2
# 2             12.2           12.2             0.0              12.2
# 3             12.2           12.2             0.0              12.2
# 4             12.2           12.2             0.0              12.2
# ..             ...            ...             ...               ...
# 515           12.2           11.2             1.0              11.8
# 516           11.4            9.6             1.8              11.0
# 517           11.0            9.8             1.2              10.6
# 518           12.2           11.4             0.8              11.8
# 519           10.6            9.2             1.4              10.2
#
#      ModelThickMean  ModelThickStd  ModeVelCoeff  EnvelopeAvgTimeDiff  \
# 0         12.200000       0.000000         0.980             0.000087
# 1         12.200000       0.000000         0.990             0.000087
# 2         12.200000       0.000000         1.000             0.000086
# 3         12.200000       0.000000         1.010             0.000085
# 4         12.200000       0.000000         1.020             0.000084
# ..              ...            ...           ...                  ...
# 515       11.845156       0.265136         0.980             0.000089
# 516       10.991719       0.333053         1.014             0.000087
# 517       10.600468       0.306663         1.012             0.000089
# 518       11.876250       0.226055         1.014             0.000086
# 519       10.202344       0.307977         0.980             0.000091
#
#      EnvelopeAvgAmpReduc  PhaseDiffMean  Win4_PeakAmp  Win4_PeakFreq  \
# 0              -0.090215      -0.820041      0.000001     47851.5625
# 1              -0.089597      -0.553822      0.000001     47851.5625
# 2              -0.089083      -0.293270      0.000001     46875.0000
# 3              -0.088695      -0.038224      0.000001     46875.0000
# 4              -0.088149       0.211493      0.000001     45898.4375
# ..                   ...            ...           ...            ...
# 515            -0.149091      -1.847189      0.000001     48828.1250
# 516            -0.190519      -2.244434      0.000001     46875.0000
# 517            -0.199816      -2.923062      0.000001     48828.1250
# 518            -0.150921      -0.784272      0.000001     46875.0000
# 519            -0.179424       1.876331      0.000001     50781.2500
#
#      Win4_fwhmFreqRange
# 0            30273.4375
# 1            31250.0000
# 2            31250.0000
# 3            31250.0000
# 4            31250.0000
# ..                  ...
# 515          30273.4375
# 516          28320.3125
# 517          29296.8750
# 518          31250.0000
# 519          30273.4375
#
# [900 rows x 13 columns]

# %%
corr = df_raw.corr()

# %%
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col1 {
#             background-color:  #d95847;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col2 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col3 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col5 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col6 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col7 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col8 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col10 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col11 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow0_col12 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col0 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col2 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col3 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col4 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col5 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col6 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col8 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col9 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col10 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col11 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow1_col12 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col0 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col3 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col4 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col5 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col6 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col7 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col8 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col9 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col10 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col11 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow2_col12 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col0 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col1 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col2 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col5 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col6 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col7 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col8 {
#             background-color:  #e7745b;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col9 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col10 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow3_col12 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow4_col0 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow4_col1 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow4_col2 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow4_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow4_col5 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow4_col6 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_78a3d14c_95f1_11eb_8963_24418c30a33frow4_col7 {
#             background-color:  #3c4ec2;
#             color:

# %%
f, ax = plt.subplots(figsize=(18, 12))
sns.heatmap(corr, vmin=-1, vmax=1, fmt='g', cmap='coolwarm', linewidths=0.75 );

# %% [markdown]
# ## Clean up cells

# %%
df_raw.columns
# Out:
# Index(['ModelThickMax', 'ModelThickMin', 'ModelThickDiff', 'ModelThickMedian',
#        'ModelThickMean', 'ModelThickStd', 'ModeVelCoeff',
#        'EnvelopeAvgTimeDiff', 'EnvelopeAvgAmpReduc', 'PhaseDiffMean',
#        'Win4_PeakAmp', 'Win4_PeakFreq', 'Win4_fwhmFreqRange'],
#       dtype='object')

# %%
#df = df_raw.drop(['ModelThickMax', 'ModelThickMin', 'ModelThickDiff', 'ModelThickMedian'], axis=1)
df = df_raw.drop(['ModelThickMax', 'ModelThickDiff', 'ModelThickMedian'], axis=1)

# %%
df.columns
# Out:
# Index(['ModelThickMin', 'ModelThickMean', 'ModelThickStd', 'ModeVelCoeff',
#        'EnvelopeAvgTimeDiff', 'EnvelopeAvgAmpReduc', 'PhaseDiffMean',
#        'Win4_PeakAmp', 'Win4_PeakFreq', 'Win4_fwhmFreqRange'],
#       dtype='object')

# %%
from sklearn import linear_model

# %%
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(df, test_size=0.2, random_state=42)

# %%
train_set
# Out:
#      ModelThickMin  ModelThickMean  ModelThickStd  ModeVelCoeff  \
# 10            11.8       12.003281       0.146756         0.980
# 334           11.6       12.431406       0.293662         1.020
# 244           11.0       12.214687       0.327480         1.020
# 298            9.2       10.235781       0.301470         0.987
# 306           12.0       12.488438       0.236188         0.990
# ..             ...             ...            ...           ...
# 106           12.0       12.203593       0.146108         0.990
# 270           10.4       12.203438       0.354734         0.980
# 480            8.4        9.957188       0.363088         1.011
# 55            10.4       11.065781       0.268580         0.986
# 102           12.0       12.215469       0.146616         1.000
#
#      EnvelopeAvgTimeDiff  EnvelopeAvgAmpReduc  PhaseDiffMean  Win4_PeakAmp  \
# 10              0.000088            -0.126508      -1.165304  1.124443e-06
# 334             0.000085            -0.139655      -0.148371  9.632608e-07
# 244             0.000084            -0.159365      -0.426356  9.296568e-07
# 298             0.000090            -0.206412       2.178800  9.568906e-07
# 306             0.000087            -0.145677      -0.668234  9.987646e-07
# ..                   ...                  ...            ...           ...
# 106             0.000087            -0.115282      -0.671808  1.149115e-06
# 270             0.000087            -0.159450      -1.505736  9.353810e-07
# 480             0.000089            -0.193960       2.269519  1.068695e-06
# 55              0.000089            -0.169885      -2.738444  1.074561e-06
# 102             0.000086            -0.120242      -0.415772  1.107304e-06
#
#      Win4_PeakFreq  Win4_fwhmFreqRange
# 10      47851.5625          30273.4375
# 334     46875.0000          31250.0000
# 244     44921.8750          31250.0000
# 298     48828.1250          31250.0000
# 306     46875.0000          30273.4375
# ..             ...                 ...
# 106     46875.0000          31250.0000
# 270     46875.0000          31250.0000
# 480     48828.1250          30273.4375
# 55      48828.1250          30273.4375
# 102     46875.0000          30273.4375
#
# [720 rows x 10 columns]

# %%
test_set
# Out:
#      ModelThickMin  ModelThickMean  ModelThickStd  ModeVelCoeff  \
# 70            10.2       11.792188       0.334984         0.980
# 447           10.4       11.447656       0.289310         1.002
# 231           11.4       12.207344       0.304322         0.990
# 208            9.2        9.687187       0.229950         1.012
# 39            11.0       11.825938       0.290720         1.020
# ..             ...             ...            ...           ...
# 517            9.8       10.600468       0.306663         1.012
# 198           10.8       11.145937       0.195370         0.997
# 399            8.4        9.751563       0.349999         0.989
# 25            11.4       11.876094       0.233792         0.980
# 84            10.2       11.795469       0.341378         1.020
#
#      EnvelopeAvgTimeDiff  EnvelopeAvgAmpReduc  PhaseDiffMean  Win4_PeakAmp  \
# 70              0.000089            -0.148979      -2.023706  1.002931e-06
# 447             0.000087            -0.156651      -1.786231  9.980378e-07
# 231             0.000087            -0.153794      -1.190440  9.802027e-07
# 208             0.000089            -0.183799       2.133621  1.160316e-06
# 39              0.000085            -0.164939      -0.915253  9.636096e-07
# ..                   ...                  ...            ...           ...
# 517             0.000089            -0.199816      -2.923062  1.090866e-06
# 198             0.000087            -0.162617      -2.034712  1.100815e-06
# 399             0.000094            -0.193849       1.194170  9.530384e-07
# 25              0.000088            -0.157284      -1.666975  9.875005e-07
# 84              0.000084            -0.179988      -1.109085  9.045968e-07
#
#      Win4_PeakFreq  Win4_fwhmFreqRange
# 70      48828.1250          31250.0000
# 447     47851.5625          33203.1250
# 231     47851.5625          31250.0000
# 208     48828.1250          30273.4375
# 39      44921.8750          32226.5625
# ..             ...                 ...
# 517     48828.1250          29296.8750
# 198     46875.0000          30273.4375
# 399     47851.5625          31250.0000
# 25      47851.5625          31250.0000
# 84      44921.8750          32226.5625
#
# [180 rows x 10 columns]

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.22.1

# %%
# https://machinelearningmastery.com/multi-output-regression-models-with-python/

# %%
X_train = train_set[['EnvelopeAvgTimeDiff', 'EnvelopeAvgAmpReduc', 'PhaseDiffMean', 'Win4_PeakAmp', 'Win4_PeakFreq', 'Win4_fwhmFreqRange']]
y_train = train_set[['ModelThickMin','ModelThickMean', 'ModelThickStd', 'ModeVelCoeff']]
X_test = test_set[['EnvelopeAvgTimeDiff', 'EnvelopeAvgAmpReduc', 'PhaseDiffMean', 'Win4_PeakAmp', 'Win4_PeakFreq', 'Win4_fwhmFreqRange']]
y_test = test_set[['ModelThickMin','ModelThickMean', 'ModelThickStd', 'ModeVelCoeff']]

# %%
X_train
# Out:
#      EnvelopeAvgTimeDiff  EnvelopeAvgAmpReduc  PhaseDiffMean  Win4_PeakAmp  \
# 10              0.000088            -0.126508      -1.165304  1.124443e-06
# 334             0.000085            -0.139655      -0.148371  9.632608e-07
# 244             0.000084            -0.159365      -0.426356  9.296568e-07
# 298             0.000090            -0.206412       2.178800  9.568906e-07
# 306             0.000087            -0.145677      -0.668234  9.987646e-07
# ..                   ...                  ...            ...           ...
# 106             0.000087            -0.115282      -0.671808  1.149115e-06
# 270             0.000087            -0.159450      -1.505736  9.353810e-07
# 480             0.000089            -0.193960       2.269519  1.068695e-06
# 55              0.000089            -0.169885      -2.738444  1.074561e-06
# 102             0.000086            -0.120242      -0.415772  1.107304e-06
#
#      Win4_PeakFreq  Win4_fwhmFreqRange
# 10      47851.5625          30273.4375
# 334     46875.0000          31250.0000
# 244     44921.8750          31250.0000
# 298     48828.1250          31250.0000
# 306     46875.0000          30273.4375
# ..             ...                 ...
# 106     46875.0000          31250.0000
# 270     46875.0000          31250.0000
# 480     48828.1250          30273.4375
# 55      48828.1250          30273.4375
# 102     46875.0000          30273.4375
#
# [720 rows x 6 columns]

# %%
y_test
# Out:
#      ModelThickMin  ModelThickMean  ModelThickStd  ModeVelCoeff
# 70            10.2       11.792188       0.334984         0.980
# 447           10.4       11.447656       0.289310         1.002
# 231           11.4       12.207344       0.304322         0.990
# 208            9.2        9.687187       0.229950         1.012
# 39            11.0       11.825938       0.290720         1.020
# ..             ...             ...            ...           ...
# 517            9.8       10.600468       0.306663         1.012
# 198           10.8       11.145937       0.195370         0.997
# 399            8.4        9.751563       0.349999         0.989
# 25            11.4       11.876094       0.233792         0.980
# 84            10.2       11.795469       0.341378         1.020
#
# [180 rows x 4 columns]

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (720, 6) (720, 4)
# (180, 6) (180, 4)

# %% [markdown]
# ## Linear Regression

# %%
model_linreg = linear_model.LinearRegression()

# %%
model_linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_hat_linreg = model_linreg.predict(X_test)

# %%
y_hat_linreg.shape
# Out:
# (180, 4)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse_linreg_ModelThickMin = mean_squared_error(y_test[['ModelThickMin']], y_hat_linreg[:,0])
mse_linreg_ModelThickMean = mean_squared_error(y_test[['ModelThickMean']], y_hat_linreg[:,1])
mse_linreg_ModelThickStd = mean_squared_error(y_test[['ModelThickStd']], y_hat_linreg[:,2])
mse_linreg_ModelVelCoeff = mean_squared_error(y_test[['ModeVelCoeff']], y_hat_linreg[:,3])
rmse_linreg_ModelThickMin = np.sqrt(mse_linreg_ModelThickMin)
rmse_linreg_ModelThickMean = np.sqrt(mse_linreg_ModelThickMean)
rmse_linreg_ModelThickStd = np.sqrt(mse_linreg_ModelThickStd)
rmse_linreg_ModelVelCoeff = np.sqrt(mse_linreg_ModelVelCoeff)

# %%
rmse_linreg_ModelThickMin, rmse_linreg_ModelThickMean, rmse_linreg_ModelThickStd, rmse_linreg_ModelVelCoeff
# Out:
# (0.5203419660386187,
#  0.34302180134768706,
#  0.052116283433044,
#  0.01725452870797496)

# %% [markdown]
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree_reg = DecisionTreeRegressor()
tree_reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
y_hat_tree_reg = tree_reg.predict(X_test)

# %%
mse_tree_reg_ModelThickMin = mean_squared_error(y_test[['ModelThickMin']], y_hat_tree_reg[:,0])
mse_tree_reg_ModelThickMean = mean_squared_error(y_test[['ModelThickMean']], y_hat_tree_reg[:,1])
mse_tree_reg_ModelThickStd = mean_squared_error(y_test[['ModelThickStd']], y_hat_tree_reg[:,2])
mse_tree_reg_ModelVelCoeff = mean_squared_error(y_test[['ModeVelCoeff']], y_hat_tree_reg[:,3])
rmse_tree_reg_ModelThickMin = np.sqrt(mse_tree_reg_ModelThickMin)
rmse_tree_reg_ModelThickMean = np.sqrt(mse_tree_reg_ModelThickMean)
rmse_tree_reg_ModelThickStd = np.sqrt(mse_tree_reg_ModelThickStd)
rmse_tree_reg_ModelVelCoeff = np.sqrt(mse_tree_reg_ModelVelCoeff)

# %%
rmse_tree_reg_ModelThickMin, rmse_tree_reg_ModelThickMean, rmse_tree_reg_ModelThickStd, rmse_tree_reg_ModelVelCoeff
# Out:
# (0.5738757124441959,
#  0.36647350811196405,
#  0.052242730185448435,
#  0.010465346252346727)

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest_reg = RandomForestRegressor()

# %%
forest_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_hat_forest_reg = forest_reg.predict(X_test)

# %%
mse_forest_reg_ModelThickMin = mean_squared_error(y_test[['ModelThickMin']], y_hat_forest_reg[:,0])
mse_forest_reg_ModelThickMean = mean_squared_error(y_test[['ModelThickMean']], y_hat_forest_reg[:,1])
mse_forest_reg_ModelThickStd = mean_squared_error(y_test[['ModelThickStd']], y_hat_forest_reg[:,2])
mse_forest_reg_ModelVelCoeff = mean_squared_error(y_test[['ModeVelCoeff']], y_hat_forest_reg[:,3])
rmse_forest_reg_ModelThickMin = np.sqrt(mse_forest_reg_ModelThickMin)
rmse_forest_reg_ModelThickMean = np.sqrt(mse_forest_reg_ModelThickMean)
rmse_forest_reg_ModelThickStd = np.sqrt(mse_forest_reg_ModelThickStd)
rmse_forest_reg_ModelVelCoeff = np.sqrt(mse_forest_reg_ModelVelCoeff)

# %%
rmse_forest_reg_ModelThickMin, rmse_forest_reg_ModelThickMean, rmse_forest_reg_ModelThickStd, rmse_forest_reg_ModelVelCoeff
# Out:
# (0.35619180226389274,
#  0.23853574126686788,
#  0.03738786017202669,
#  0.007346893417529186)

# %% [markdown]
# ## SVM Regression

# %%
from sklearn.svm import SVR

# %%
svm_reg = SVR(kernel='poly', degree=5, C=100, epsilon=0.1)
svm_reg.fit(X_train, y_train['ModeVelCoeff'])
# Out:
# SVR(C=100, cache_size=200, coef0=0.0, degree=5, epsilon=0.1, gamma='scale',
#     kernel='poly', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_hat_svm_reg = svm_reg.predict(X_test)

# %%
rmse_svm_reg = np.sqrt(mean_squared_error(y_test[['ModeVelCoeff']], y_hat_svm_reg))

# %%
rmse_svm_reg
# Out:
# 0.013156318868564058

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

# %%
scaler_X.fit(X_train)
scaler_y.fit(y_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
#print(scaler_X.transform(X_test))

# %%
#print(scaler_y.transform(y_test))

# %%
X_scaled = scaler_X.transform(X_train)
y_scaled = scaler_y.transform(y_train)

# %%
#y_scaled[:,1]

# %% [markdown]
# ### Random forest

# %%
forest_reg_scaled = RandomForestRegressor()
forest_reg_scaled.fit(X_scaled, y_scaled)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
y_hat_forest_reg_scaled = forest_reg_scaled.predict(scaler_X.transform(X_test))

# %%
rmse_forest_scaled_scaler_ModelThickMin = np.sqrt(mean_squared_error(y_test[['ModelThickMin']], scaler_y.inverse_transform(y_hat_forest_reg_scaled)[:,0]))
rmse_forest_scaled_scaler_ModelThickMean = np.sqrt(mean_squared_error(y_test[['ModelThickMean']], scaler_y.inverse_transform(y_hat_forest_reg_scaled)[:,1]))
rmse_forest_scaled_scaler_ModelThickStd = np.sqrt(mean_squared_error(y_test[['ModelThickStd']], scaler_y.inverse_transform(y_hat_forest_reg_scaled)[:,2]))
rmse_forest_scaled_scaler_ModelVelCoeff = np.sqrt(mean_squared_error(y_test[['ModeVelCoeff']], scaler_y.inverse_transform(y_hat_forest_reg_scaled)[:,3]))

# %%
rmse_forest_scaled_scaler_ModelThickMin, rmse_forest_scaled_scaler_ModelThickMean, rmse_forest_scaled_scaler_ModelThickStd, rmse_forest_scaled_scaler_ModelVelCoeff
# Out:
# (0.346473664222838,
#  0.19193145188015176,
#  0.032462690042080446,
#  0.005639166125409481)

# %% [markdown]
# ### Decision tree

# %%
tree_reg_scaled = DecisionTreeRegressor()
tree_reg_scaled.fit(X_scaled, y_scaled)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
y_hat_tree_reg_scaled = tree_reg_scaled.predict(scaler_X.transform(X_test))

# %%
rmse_tree_scaled_scaler_ModelThickMin = np.sqrt(mean_squared_error(y_test[['ModelThickMin']], scaler_y.inverse_transform(y_hat_tree_reg_scaled)[:,0]))
rmse_tree_scaled_scaler_ModelThickMean = np.sqrt(mean_squared_error(y_test[['ModelThickMean']], scaler_y.inverse_transform(y_hat_tree_reg_scaled)[:,1]))
rmse_tree_scaled_scaler_ModelThickStd = np.sqrt(mean_squared_error(y_test[['ModelThickStd']], scaler_y.inverse_transform(y_hat_tree_reg_scaled)[:,2]))
rmse_tree_scaled_scaler_ModelVelCoeff = np.sqrt(mean_squared_error(y_test[['ModeVelCoeff']], scaler_y.inverse_transform(y_hat_tree_reg_scaled)[:,3]))

# %%
rmse_tree_scaled_scaler_ModelThickMin, rmse_tree_scaled_scaler_ModelThickMean, rmse_tree_scaled_scaler_ModelThickStd, rmse_tree_scaled_scaler_ModelVelCoeff
# Out:
# (0.5314550257965809,
#  0.2338446254991954,
#  0.05180488343661522,
#  0.009000613631165867)

# %% [markdown]
# ### Linear regression

# %%
model_scaled = linear_model.LinearRegression()

# %%
model_scaled.fit(X_scaled, y_scaled)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_hat_linreg_scaled = model_scaled.predict(scaler_X.transform(X_test))

# %%
rmse_linreg_scaled_ModelThickMin = np.sqrt(mean_squared_error(y_test[['ModelThickMin']], scaler_y.inverse_transform(y_hat_linreg_scaled)[:,0]))
rmse_linreg_scaled_ModelThickMean = np.sqrt(mean_squared_error(y_test[['ModelThickMean']], scaler_y.inverse_transform(y_hat_linreg_scaled)[:,1]))
rmse_linreg_scaled_ModelThickStd = np.sqrt(mean_squared_error(y_test[['ModelThickStd']], scaler_y.inverse_transform(y_hat_linreg_scaled)[:,2]))
rmse_linreg_scaled_ModelVelCoeff = np.sqrt(mean_squared_error(y_test[['ModeVelCoeff']], scaler_y.inverse_transform(y_hat_linreg_scaled)[:,3]))

# %%
rmse_linreg_scaled_ModelThickMin, rmse_linreg_scaled_ModelThickMean, rmse_linreg_scaled_ModelThickStd, rmse_linreg_scaled_ModelVelCoeff
# Out:
# (0.5203419660844016,
#  0.3430218020420487,
#  0.052116283525365265,
#  0.017254528714979695)

# %% [markdown]
# ## Summary

# %%
#Linear regression errors
rmse_linreg_ModelThickMin, rmse_linreg_ModelThickMean, rmse_linreg_ModelThickStd, rmse_linreg_ModelVelCoeff
# Out:
# (0.5203419660386187,
#  0.34302180134768706,
#  0.052116283433044,
#  0.01725452870797496)

# %%
#Normalized linear regression errors
rmse_linreg_scaled_ModelThickMin, rmse_linreg_scaled_ModelThickMean, rmse_linreg_scaled_ModelThickStd, rmse_linreg_scaled_ModelVelCoeff
# Out:
# (0.5203419660844016,
#  0.3430218020420487,
#  0.052116283525365265,
#  0.017254528714979695)

# %%
#Decision tree regression errors
rmse_tree_reg_ModelThickMin, rmse_tree_reg_ModelThickMean, rmse_tree_reg_ModelThickStd, rmse_tree_reg_ModelVelCoeff
# Out:
# (0.5738757124441959,
#  0.36647350811196405,
#  0.052242730185448435,
#  0.010465346252346727)

# %%
#Normalized decision tree regression errors
rmse_tree_scaled_scaler_ModelThickMin, rmse_tree_scaled_scaler_ModelThickMean, rmse_tree_scaled_scaler_ModelThickStd, rmse_tree_scaled_scaler_ModelVelCoeff
# Out:
# (0.5314550257965809,
#  0.2338446254991954,
#  0.05180488343661522,
#  0.009000613631165867)

# %%
#Random forest regression errors
rmse_forest_reg_ModelThickMin, rmse_forest_reg_ModelThickMean, rmse_forest_reg_ModelThickStd, rmse_forest_reg_ModelVelCoeff
# Out:
# (0.35619180226389274,
#  0.23853574126686788,
#  0.03738786017202669,
#  0.007346893417529186)

# %%
#Normalized random forest regression errors
rmse_forest_scaled_scaler_ModelThickMin, rmse_forest_scaled_scaler_ModelThickMean, rmse_forest_scaled_scaler_ModelThickStd, rmse_forest_scaled_scaler_ModelVelCoeff
# Out:
# (0.346473664222838,
#  0.19193145188015176,
#  0.032462690042080446,
#  0.005639166125409481)

# %% [markdown]
# **Making a comparison table for best performing ML model:**

# %%
test = y_test.copy(deep=True)

# %%
y_hat_forest_reg_scaled_inverse = scaler_y.inverse_transform(y_hat_forest_reg_scaled)

# %%
test['Predicted MTMin'] = y_hat_forest_reg_scaled_inverse[:,0]
test['Predicted MTMean'] = y_hat_forest_reg_scaled_inverse[:,1]
test['Predicted MTStd'] = y_hat_forest_reg_scaled_inverse[:,2]
test['Predicted MVelCoeff'] = y_hat_forest_reg_scaled_inverse[:,3]

# %%
test.columns
# Out:
# Index(['ModelThickMin', 'ModelThickMean', 'ModelThickStd', 'ModeVelCoeff',
#        'Predicted MTMin', 'Predicted MTMean', 'Predicted MTStd',
#        'Predicted MVelCoeff'],
#       dtype='object')

# %%
test = test[['ModelThickMin', 'Predicted MTMin', 'ModelThickMean', 'Predicted MTMean', 
             'ModelThickStd', 'Predicted MTStd','ModeVelCoeff','Predicted MVelCoeff']]

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.min_rows', 100)

# %%
test
# Out:
#      ModelThickMin  Predicted MTMin  ModelThickMean  Predicted MTMean  \
# 70            10.2           10.412       11.792188         11.785636
# 447           10.4           10.680       11.447656         11.721148
# 231           11.4           11.074       12.207344         12.079022
# 208            9.2            9.158        9.687187          9.848936
# 39            11.0           10.382       11.825938         11.874247
# 351           12.2           12.118       12.416406         12.348851
# 299           12.4           12.254       12.602344         12.486596
# 110           12.0           11.934       12.210469         12.127918
# 72            10.2           10.542       11.792188         11.854733
# 86            10.2           10.358       11.792188         11.814353
# 139           11.2           11.160       12.010469         12.085741
# 153           10.0           10.542       11.202031         11.472191
# 421            9.6            9.942       10.781406         10.946995
# 120           11.6           11.080       12.072188         12.108475
# 331            8.0            8.284        9.749375          9.706672
# 210           10.2           10.206       10.527657         10.622067
# 168           10.6           10.702       11.983281         11.980819
# 42             9.8            9.524       10.284062         10.212273
# 67            11.2           11.324       12.418906         12.236386
# 67            10.2           10.372       11.795469         11.707358
# 211           11.8           11.102       12.290938         12.126744
# 361           10.0            9.214       10.815625         10.379861
# 308           10.6           10.762       12.393906         12.096494
# 333           11.6           11.560       12.431406         12.363809
# 162           10.0            9.738       10.499687         10.839897
# 344           11.2           11.456       12.387500         12.387261
# 30            11.4           10.852       11.886250         11.882708
# 457            9.2            9.624       10.789844         10.877486
# 278           11.0           11.154       12.227657         12.376711
# 142            8.4            9.324        9.601875         10.590172
# 260           10.6           11.010       12.184531         12.051281
# 376            8.6            8.510        9.590625          9.789945
# 298           12.4           12.364       12.602344         12.570953
# 151           10.2           10.222       11.995313         11.853788
# 235            8.4            9.128        9.584219         10.580637
# 295            9.8            9.882       10.828906         10.744802
# 23            11.4           10.636       11.885469         11.888183
# 209            8.8            8.948        9.988594          9.985977
# 51            11.4           10.862       12.045625         12.019325
# 209           12.2           12.236       12.400625         12.444700
# 63            10.6           10.776       11.818750         11.827788
# 239           11.4           11.206       12.188438         12.263747
# 370           10.8           10.974       12.381094         12.375964
# 364           10.4            9.972       10.869375         10.936875
# 272           11.2           11.688       12.434843         12.258030
# 245           12.2           12.192       12.302187         12.401111
# 215           11.8           11.506       12.269218         12.283086
# 139           11.2           10.936       11.843750         11.924758
# 114           12.2           12.176       12.302657         12.338922
# 452           10.6           10.768       12.200781         12.120481
# ..             ...              ...             ...               ...
# 202           12.2           11.880       12.555625         12.374470
# 363            9.8           10.096       11.206250         11.225969
# 363           10.8           10.896       12.401563         12.361633
# 65            10.2           10.204       11.795469         11.659406
# 409            9.2            8.856       10.252969          9.892495
# 291           12.4           12.372       12.610781         12.574281
# 223           11.8           11.890       12.016875         12.089335
# 477           10.0            9.982       11.420313         11.231227
# 106           10.6           10.876       11.793125         11.891281
# 235           11.4           10.774       12.188438         12.032059
# 250           11.0           10.760       12.168437         11.907864
# 49            11.0           10.794       11.837032         11.888217
# 277            9.0            8.790       10.424375         10.308314
# 309           12.0           11.806       12.488438         12.393963
# 329            9.0            9.320       10.199062         10.242242
# 275           10.6           11.010       12.184531         12.051281
# 514            8.4            8.818        9.628438         10.140906
# 165           10.6           10.548       11.983281         11.887394
# 133           11.2           10.498       11.828750         11.872313
# 33            11.4           10.814       11.886250         11.919172
# 31            11.4           11.016       11.886250         11.924650
# 293            8.8            8.640       10.181406         10.032109
# 24             9.0            8.908       10.391250         10.314873
# 138           11.4           11.262       12.218906         12.255209
# 50             8.8            9.000       10.378906         10.243581
# 109           12.0           12.078       12.203593         12.282897
# 77            10.2           10.684       11.814531         11.839459
# 32             9.2            9.082       10.198125         10.108417
# 312           12.0           11.574       12.468750         12.274998
# 82            10.2           10.372       11.795469         11.707358
# 321           11.6           11.426       12.435469         12.326145
# 269            9.0            8.642        9.778593          9.762547
# 313            8.4            8.482        9.824062          9.869495
# 360           10.8           11.032       12.401563         12.372666
# 107           10.8           10.854       10.899219         11.032933
# 84            11.6           11.490       12.240000         12.320008
# 5             11.8           11.776       12.011875         11.976143
# 54            10.6           10.324       11.803281         11.881685
# 354            8.4            8.756       10.192812         10.170444
# 82            11.4           10.904       11.733750         11.808227
# 323           11.6           11.390       12.435469         12.362441
# 367           11.0           11.266       12.416093         12.349163
# 97            12.4           12.426       12.400000         12.443683
# 64            10.0            9.968       11.213750         11.207314
# 196           10.6           11.158       12.408594         12.221366
# 517            9.8            9.614       10.600468         10.631678
# 198           10.8           10.286       11.145937         11.257547
# 399            8.4            8.344        9.751563          9.730014
# 25            11.4           10.918       11.876094         11.982278
# 84            10.2           10.230       11.795469         11.813644
#
#      ModelThickStd  Predicted MTStd  ModeVelCoeff  Predicted MVelCoeff
# 70        0.334984         0.321992         0.980              0.98078
# 447       0.289310         0.291044         1.002              1.00199
# 231       0.304322         0.290219         0.990              0.99365
# 208       0.229950         0.256466         1.012              1.00676
# 39        0.290720         0.323209         1.020              1.01667
# 351       0.148212         0.155789         0.997              0.99870
# 299       0.146133         0.144776         1.020              1.01649
# 110       0.145991         0.140362         0.980              0.98272
# 72        0.334984         0.314183         1.000              0.99685
# 86        0.334984         0.326931         0.990              0.98846
# 139       0.296737         0.286004         1.020              1.01590
# 153       0.316691         0.285402         1.020              1.00961
# 421       0.332448         0.301884         1.012              0.99926
# 120       0.236422         0.292226         0.980              0.98571
# 331       0.374896         0.353628         0.981              0.98521
# 210       0.191085         0.201879         1.020              1.01215
# 168       0.338421         0.327453         1.010              1.01006
# 42        0.231653         0.254745         0.996              1.00098
# 67        0.307811         0.289941         1.015              1.01768
# 67        0.341378         0.325091         1.000              1.00647
# 211       0.233099         0.296109         0.990              1.00349
# 361       0.296035         0.313820         0.986              0.99299
# 308       0.367729         0.322621         1.013              1.00357
# 333       0.293662         0.267393         1.010              1.00997
# 162       0.227437         0.304476         0.999              0.99844
# 344       0.326902         0.280386         1.020              1.01614
# 30        0.233004         0.298161         0.980              0.98491
# 457       0.351194         0.325074         1.007              1.00654
# 278       0.335659         0.317633         1.020              1.00862
# 142       0.322223         0.334983         0.989              0.98889
# 260       0.345793         0.307353         0.980              0.98284
# 376       0.320144         0.332411         0.981              0.98589
# 298       0.146133         0.144869         1.010              1.01106
# 151       0.337089         0.339202         1.012              1.01395
# 235       0.328430         0.339108         0.987              1.00849
# 295       0.301171         0.274817         0.993              1.00124
# 23        0.230527         0.319780         1.010              1.01494
# 209       0.350888         0.298859         0.992              0.98857
# 51        0.271640         0.305731         1.015              1.01157
# 209       0.147958         0.147593         1.020              1.01717
# 63        0.308987         0.293883         1.010              1.01018
# 239       0.300623         0.295946         1.020              1.01671
# 370       0.339782         0.332106         0.980              0.98042
# 364       0.235277         0.300526         1.002              1.00398
# 272       0.312880         0.241862         1.011              1.01227
# 245       0.100015         0.142829         1.018              1.01583
# 215       0.238950         0.272003         0.980              0.98454
# 139       0.266958         0.292946         1.005              1.00587
# 114       0.100004         0.116186         0.984              0.98605
# 452       0.343053         0.322602         1.002              1.00319
# ..             ...              ...           ...                  ...
# 202       0.191205         0.223394         1.003              1.01038
# 363       0.316388         0.305526         0.999              0.99402
# 363       0.342548         0.335950         1.010              1.01176
# 65        0.341378         0.332166         0.980              0.98459
# 409       0.300597         0.301813         1.019              1.00696
# 291       0.147672         0.144092         0.990              0.99129
# 223       0.146781         0.137319         0.996              0.99114
# 477       0.311108         0.318476         0.996              0.99886
# 106       0.318150         0.291174         0.999              0.99347
# 235       0.300623         0.316955         0.980              0.98827
# 250       0.329907         0.302538         0.980              0.98674
# 49        0.283236         0.293536         1.020              1.01816
# 277       0.326422         0.339714         1.001              1.00522
# 309       0.236188         0.247124         1.020              1.01870
# 329       0.317633         0.286759         1.001              0.99490
# 275       0.345793         0.307353         0.980              0.98284
# 514       0.298556         0.327126         1.011              1.00752
# 165       0.338421         0.334017         0.980              0.98231
# 133       0.264060         0.324806         0.981              0.98132
# 33        0.233004         0.317294         1.010              1.01564
# 31        0.233004         0.275157         0.990              0.99236
# 293       0.321058         0.322880         0.985              0.99880
# 24        0.346164         0.333882         0.997              1.00624
# 138       0.287317         0.296197         1.019              1.01446
# 50        0.360469         0.323395         0.998              1.00296
# 109       0.146108         0.143179         1.020              1.01407
# 77        0.319021         0.300325         1.000              1.00088
# 32        0.316840         0.285112         1.008              1.00426
# 312       0.236256         0.235814         1.000              1.00427
# 82        0.341378         0.325091         1.000              1.00647
# 321       0.292772         0.277184         0.990              0.98857
# 269       0.310984         0.314717         0.988              0.98552
# 313       0.330161         0.332755         0.996              0.98912
# 360       0.342548         0.325604         0.980              0.98041
# 107       0.100036         0.126149         1.008              1.00897
# 84        0.267897         0.279415         0.985              0.98208
# 5         0.145561         0.144458         0.980              0.98108
# 54        0.325447         0.336372         1.020              1.01361
# 354       0.353972         0.333004         0.997              0.99727
# 82        0.189938         0.270688         1.003              1.00822
# 323       0.292772         0.285001         1.010              1.00985
# 367       0.319436         0.304026         1.000              0.99951
# 97        0.000000         0.014849         1.000              1.00050
# 64        0.320279         0.320463         0.991              0.99453
# 196       0.338633         0.306710         1.009              1.01693
# 517       0.306663         0.299300         1.012              1.00927
# 198       0.195370         0.284640         0.997              1.00591
# 399       0.349999         0.343945         0.989              0.99167
# 25        0.233792         0.307190         0.980              0.98302
# 84        0.341378         0.339892         1.020              1.01682
#
# [180 rows x 8 columns]
